# %%
import pandas as pd
import numpy as np
from typing import List
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re , logging ,unicodedata
from collections import Counter
from pyxlsb import open_workbook


# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='[%(levelname)s] %(message)s'
)

def load_data(filepath):
    """Load data from an Excel file (.xlsx or .xlsb) with logging & error handling."""

    logging.info(f"Loading file: {filepath}")

    try:
        if filepath.endswith(".xlsb") or filepath.endswith(".xls"):
            logging.info(" XLSB/XLS file is Detected .")

            data = []
            with open_workbook(filepath) as wb:
                with wb.get_sheet(1) as sheet:
                    for row in sheet.rows():
                        data.append([item.v for item in row])

            if not data:
                raise ValueError("The file is empty or could not be read.")

            df = pd.DataFrame(data[1:], columns=data[0])
        
        else:
            logging.info("XLSX file NOT DETECTED , Reading file using pandas.read_excel().")
            df = pd.read_excel(filepath)

        logging.info("File loaded successfully")
        return df

    except Exception as e:
        logging.error(f"FAILED to load File : {e}")
        raise RuntimeError(f"Could not load file '{filepath}'") from e
    

def analyze_categories(df, category_col="Nature"):
    """
    Analyze the distribution of categories and return a DataFrame
    """
    # Check if column exists
    if category_col not in df.columns:
        logging.error(f"Column '{category_col}' does not exist in the DataFrame.")
        return None

    # Count categories
    category_counts = Counter(df[category_col].dropna())
    total_count = sum(category_counts.values())

    # Build the DataFrame
    Category_Distribution = pd.DataFrame({
        'Category': list(category_counts.keys()),
        'Count': list(category_counts.values())
    })

    # Add percentage column
    Category_Distribution['Percentage % '] = round((Category_Distribution['Count'] / total_count) * 100,2)

    # Sort by Count descending
    Category_Distribution = Category_Distribution.sort_values(by='Count', ascending=False).reset_index(drop=True)

    return Category_Distribution

def build_category_profiles(df, nature_col='Nature', description_col="Libellé produit"):
    """
    Construit un profil textuel pour chaque catégorie basé sur les descriptions. Retourne un dictionnaire : {category: texte_concatené_descriptions}
    """
    logging.info("=== Profiles Construction ===")
    
    category_profiles = {}
    
    # Boucle sur toutes les catégories uniques non-null
    for category in df[nature_col].dropna().unique():
        # Filtrer les lignes appartenant à cette catégorie
        category_data = df[df[nature_col] == category]
        
        # Récupérer les descriptions non-null et convertir en string
        descriptions = category_data[description_col].dropna().astype(str)
        
        # Concaténer toutes les descriptions en une seule chaîne
        category_profiles[category] = ' '.join(descriptions)

    logging.info(f"Profils créés pour {len(category_profiles)} catégories")
    return category_profiles

def detect_miscategorized_products(df, nature_col='Nature', description_col='Libellé produit', threshold=0.3):
    """
    Détecte les produits potentiellement mal catégorisés et propose des recatégorisations basées sur la similarité textuelle.
    Paramètres:
    - threshold: seuil de similarité minimum pour considérer qu'un produit est bien catégorisé
    """
    logging.info("=== DÉTECTION DES PRODUITS MAL CATÉGORISÉS ===")
    
    # Construire les profils de catégories
    category_profiles = build_category_profiles(df, nature_col, description_col)
    
    # Préparer les données pour la vectorisation
    categories = list(category_profiles.keys())
    category_texts = [category_profiles[cat] for cat in categories]
    
    # Vectorisation TF-IDF
    logging.info("Vectorisation TF-IDF en cours...")
    vectorizer = TfidfVectorizer(
        max_features=500,
        ngram_range=(1, 3),
        min_df=2,
        stop_words=None  # Vous pouvez ajouter des stop words français si nécessaire
    )
    
    # Fit sur les profils de catégories
    category_vectors = vectorizer.fit_transform(category_texts)
    
    # Analyser chaque produit
    results = []
    df_copy = df.copy()
    
    logging.info(f"Analyse de {len(df)} produits...")
    for idx, row in df.iterrows():
        if idx % 1000 == 0:
            logging.info(f"  Progression : {idx}/{len(df)}")
        
        current_category = row[nature_col]
        description = str(row[description_col]) if pd.notna(row[description_col]) else ""
        
        if pd.isna(current_category) or description == "":
            continue
        
        # Vectoriser la description du produit
        product_vector = vectorizer.transform([description])
        
        # Calculer la similarité avec toutes les catégories
        similarities = cosine_similarity(product_vector, category_vectors)[0]
        
        # Trouver la meilleure catégorie
        best_category_idx = np.argmax(similarities)
        best_category = categories[best_category_idx]
        best_similarity = similarities[best_category_idx]
        
        # Similarité avec la catégorie actuelle
        if current_category in categories:
            current_category_idx = categories.index(current_category)
            current_similarity = similarities[current_category_idx]
        else:
            current_similarity = 0
        
        # Détecter si le produit est mal catégorisé
        is_miscategorized = (best_category != current_category and 
                            best_similarity > current_similarity + 0.1)
        
        if is_miscategorized:
            results.append({
                'index': idx,
                'description': description[:100], 
                'current_category': current_category,
                'current_similarity': round(current_similarity, 3),
                'suggested_category': best_category,
                'suggested_similarity': round(best_similarity, 3),
                'confidence': round(best_similarity - current_similarity, 3)
            })
            
            # Mettre à jour la catégorie dans le DataFrame
            df_copy.at[idx, nature_col] = best_category
    
    logging.info(f"{len(results)} produits mal catégorisés détectés")
    
    return df_copy, pd.DataFrame(results)

def extract_all_dimensions(text: str) -> List[str]:
    """
    Extracts dimensions from the Libellé produit
    """
    if pd.isna(text) or not text:
        return []
    
    text = str(text)
    text_lower = text.lower().replace(',', '.') # Normalize decimals
    
    found_values = []

  # --- 1. MULTI-DIMENSIONS (12x45, 12x45x56) ---
    # On ajoute un groupe optionnel à la fin : (?:\s*[xX/*×]\s*(\d+(?:\.\d+)?))?
    multi_dim_pattern = r'(\d+(?:\.\d+)?)\s*(?:cm|mm|m)?\s*[xX/*×]\s*(\d+(?:\.\d+)?)(?:\s*(?:cm|mm|m)?\s*[xX/*×]\s*(\d+(?:\.\d+)?))?'
    
    for match in re.finditer(multi_dim_pattern, text_lower):
        # On récupère tous les groupes qui ne sont pas None
        parts = [p for p in match.groups() if p]
        
        # Filtre de sécurité (< 3000)
        if len(parts) >= 2 and all(float(p) < 3000 for p in parts):
            found_values.append("x".join(parts))

    # --- 2. LABELED DIMENSIONS (H150, L:200) ---
    labeled_patterns = [
        r'(?:diam[èe]tre|diam\.?|ø)\s*[:=]?\s*(\d+(?:\.\d+)?)',
        r'(?:longueur|length|long\.?|L)\s*[:=]?\s*(\d+(?:\.\d+)?)',
        r'(?:largeur|width|larg\.?|W)\s*[:=]?\s*(\d+(?:\.\d+)?)',
        r'(?:hauteur|height|haut\.?|H)\s*[:=]?\s*(\d+(?:\.\d+)?)',
        r'(?:profondeur|depth|prof\.?|D|P)\s*[:=]?\s*(\d+(?:\.\d+)?)',
        r'(?:epaisseur|épaisseur|thickness|ep\.)\s*[:=]?\s*(\d+(?:\.\d+)?)'
    ]
    for pattern in labeled_patterns:
        for match in re.finditer(pattern, text_lower):
            found_values.append(match.group(1))

    # --- 3. STANDALONE UNITS ---
    # A number followed immediately by a unit
    unit_pattern = r'(\d+(?:\.\d+)?)\s*(cm|mm|m)\b'
    for match in re.finditer(unit_pattern, text_lower):
        val = match.group(1)
        # Check if this value is already part of a list
        is_duplicate = any(val in dim for dim in found_values if 'x' in dim)
        if not is_duplicate:
            found_values.append(val)

    # --- CLEANUP  ---
    seen = set()
    unique_final = []
    for v in found_values:
        if v not in seen:
            seen.add(v)
            unique_final.append(v)

    return unique_final

# Helper function to remove accents and standrize the text
def remove_accents(input_str):
    if not input_str:
        return ""
    org_form = unicodedata.normalize('NFKD', str(input_str))
    return "".join([c for c in org_form if not unicodedata.combining(c)])

def extract_colors(text):
    """
    Extracts colors using a comprehensive French/English dictionary 
    """
    if pd.isna(text) or text == "":
        return []

    # 1. CLEANING: Lowercase, remove accents, replace separators
    # "Brun-Chocolat" becomes "brun chocolat" so regex \b works
    clean_text = remove_accents(str(text)).lower()
    clean_text = clean_text.replace('-', ' ').replace('/', ' ').replace(':', ' ').replace('+', ' ')
    found_colors = []

    # 2. THE MEGA-MAP (Grouped by Color Family)
    # The Key is the "Standard Name"and The Value is the Regex matching all variations.
    color_map = {
        # --- BROWNS ---
        'marron': r'\bmarron(?:s)?\b|\bbrun(?:e|s|es)?\b|\bbrown\b|\bchocolat\b|\bcacao\b|\bcafe\b|\btabac\b|\bcoffee\b|\bnoisette\b|\bchatain\b',
        'camel': r'\bcamel\b|\bcognac\b|\bcaramel\b|\bocre\b|\bbrique\b|\brouille\b|\brust\b|\bterracotta\b|\bhale\b',
        'bois': r'\bbois\b|\bwood\b|\bchene\b|\boak\b|\bhetre\b|\bnoyer\b|\bwalnut\b|\bteck\b|\bacacia\b|\bpin\b|\bbambou\b|\brotin\b|\bosier\b|\bmerisier\b|\bolivier\b|\bpalissandre\b|\bhevea\b',

        # --- WHITES / NEUTRALS ---
        'blanc': r'\bblanc(?:he|s|hes)?\b|\bwhite\b|\bneige\b',
        'beige': r'\bbeige(?:s)?\b|\bsable\b|\bsand\b|\bcream\b|\bcreme\b|\bchampagne\b',
        'naturel': r'\bnatur(?:el|elle|els|elles)\b|\bneutre\b|\braw\b|\bbrut\b',
        'ivoire': r'\bivoire\b|\bivory\b|\becru\b|\bcoquille\b|\bvanille\b',
        'transparent': r'\btransparent(?:e|s|es)?\b|\bcristal\b|\bclear\b|\bverre\b',

        # --- GRAYS / BLACKS ---
        'noir': r'\bnoir(?:e|s|es)?\b|\bblack\b|\bcarbon(?:e)?\b|\bencre\b|\bebene\b',
        'gris': r'\bgris(?:e|es)?\b|\bgrey\b|\bgray\b|\banthracite\b|\bbeton\b|\bconcrete\b|\bardois(?:e)?\b|\bmetal\b|\bacier\b|\bplomb\b|\btain\b|\bgalet\b|\bsouris\b',
        'taupe': r'\btaupe\b|\bgrege\b',

        # --- BLUES ---
        'bleu': r'\bbleu(?:e|s|es)?\b|\bblue\b|\bmarine\b|\bnavy\b|\bazur\b|\bcyan\b|\bturquoise\b|\bindigo\b|\bdenim\b|\bpetrole\b|\bcanard\b|\bnuit\b|\bciel\b|\bsaphir\b|\broi\b',

        # --- GREENS ---
        'vert': r'\bvert(?:e|s|es)?\b|\bgreen\b|\bkaki\b|\bkhaki\b|\bolive\b|\bsauge\b|\bforet\b|\bforest\b|\bmenthe\b|\bmint\b|\banis\b|\bsapin\b|\bmeraude\b|\btilleul\b|\bpistache\b',

        # --- REDS / PINKS ---
        'rouge': r'\brouge(?:s)?\b|\bred\b|\bbordeaux\b|\bcerise\b|\bcherry\b|\bgrenat\b|\bburgundy\b|\brubis\b|\bcarmin\b|\btomate\b|\bcoquelicot\b',
        'rose': r'\brose(?:s)?\b|\bpink\b|\bpoudr(?:e)?\b|\bfushia\b|\bfuchsia\b|\bcorail\b|\bcoral\b|\bsaumon\b|\bpeche\b|\bmagenta\b|\bframboise\b',
        'violet': r'\bviolet(?:te|s|tes)?\b|\bpurple\b|\bprune\b|\bplum\b|\blilas\b|\baubergine\b|\bmauve\b|\bparme\b|\bvioline\b',

        # --- YELLOWS / ORANGES ---
        'jaune': r'\bjaune(?:s)?\b|\byellow\b|\bmoutarde\b|\bmustard\b|\bcitron\b|\blemon\b|\bsoleil\b|\bpaille\b|\bcurry\b',
        'orange': r'\borange(?:s)?\b|\bmandarine\b|\btangerine\b|\babricot\b',

        # --- METALLICS ---
        'doré': r'\bdor(?:e|ee|es|ees)?\b|\bgold(?:en)?\b|\blaiton\b|\bbrass\b',
        'argenté': r'\bargent(?:e|ee|es|ees)?\b|\bsilver\b|\bchrom(?:e|ee|es|ees)?\b|\binox\b',
        'cuivre': r'\bcuivr(?:e|ee|es|ees)?\b|\bcopper\b|\bbronze\b',

        # --- PATTERNS ---
        'multicolore': r'\bmulticolore\b|\bmulticouleur\b|\bcolor(?:e|ee|es|ees)\b|\bimprim(?:e)?\b|\bmotif(?:s)?\b|\brayur(?:e|es)\b|\bpatchwork\b',
    }

    # 3. SEARCH THE MAP
    for standard_name, pattern in color_map.items():
        if re.search(pattern, clean_text):
            found_colors.append(standard_name)

    # 4. SAFETY NET (Context Extraction)
    # If we haven't found a color yet, look for explicit labels like "Couleur : X"
    # This catches special colors we didn't list (e.g., "Couleur : Whisky")
    if not found_colors:
        context_pattern = r'(?:couleur|coloris|teinte|finition|color)\s*(?:\:)?\s*([a-z]{3,15})'
        match = re.search(context_pattern, clean_text)
        if match:
            extracted_word = match.group(1)
            if extracted_word not in ['le', 'la', 'de', 'du', 'des', 'et', 'pour', 'avec']:
                found_colors.append(extracted_word)

    # Remove duplicates
    return list(set(found_colors))

def extract_features(df, description_col='Description'):
    """
    Extracts dimensions and colors, handles List returns, and calculates correct stats.
    """
    logging.info("=== EXTRACTION DES DIMENSIONS ET COULEURS ===")
    
    # Work on a copy to avoid SettingWithCopyWarning
    df_copy = df.copy()
    
    # 1. Apply the functions (Ensure you have imported extract_all_dimensions and extract_colors)
    logging.info(" Extraction des dimensions en cours...")
    df_copy['dimensions_extraites'] = df_copy[description_col].apply(extract_all_dimensions)
    
    logging.info("Extraction des couleurs en cours...")
    df_copy['couleurs_extraites'] = df_copy[description_col].apply(extract_colors)
    
    # 2. Calculate Statistics
    # Since the columns contain lists [], .notna() doesn't work. 
    # We check if the list has a length > 0.
    dim_count = df_copy['dimensions_extraites'].apply(lambda x: len(x) > 0).sum()
    color_count = df_copy['couleurs_extraites'].apply(lambda x: len(x) > 0).sum()
    
    total = len(df)
    
    # 3. Print Results
    logging.info(f"Dimensions trouvées : {dim_count} produits ({dim_count/total*100:.1f}%)")
    logging.info(f"Couleurs trouvées   : {color_count} produits ({color_count/total*100:.1f}%)")

    return df_copy


if __name__ == "__main__":

    filepath = r"C:\Users\yo-un\OneDrive\Desktop\Internship_Use_Case\Ecommerce_Data\Ecommerce_sales.xlsb"
    
    # 1. Data Loading
    df = load_data(filepath)
    
    # 2. Analyze Categories
    Analyse_Categories = analyze_categories(df, category_col="Nature")
    
    # 3. Detect & Fix Categories 
    # This creates 'Cat_Verified_df', which has the corrected 'Nature' column
    Cat_Verified_df, Mis_Categorized_Products = detect_miscategorized_products(
        df, 
        nature_col='Nature', 
        description_col='Libellé produit', 
        threshold=0.3
    )
    
    # 4. Extract Features on the CORRECTED Dataset
    # We pass 'Cat_Verified_df' here, not 'df'
    Final_Dataset = extract_features(Cat_Verified_df, description_col='Libellé produit')

    # 5. Convert Lists to Strings for better readability in CSV file
    Final_Dataset['Product_Dimensions'] = Final_Dataset['dimensions_extraites'].apply(lambda x: ', '.join(x) if isinstance(x, list) else '')
    Final_Dataset['Product_Couleurs'] = Final_Dataset['couleurs_extraites'].apply(lambda x: ', '.join(x) if isinstance(x, list) else '')    
    Final_Dataset.drop(columns=['dimensions_extraites', 'couleurs_extraites'], inplace=True)
    # Save to CSV
    output_path = r"C:\Users\yo-un\OneDrive\Desktop\Internship_Use_Case\Ecommerce_Data\Exported_Ecommerce_sales.csv"
    Final_Dataset.to_csv(output_path, index=False, encoding='utf-8-sig', sep=';')
    logging.info(f"Dataset saved to {output_path}")
# Out:
# [INFO] Loading file: C:\Users\yo-un\OneDrive\Desktop\Internship_Use_Case\Ecommerce_Data\Ecommerce_sales.xlsb
# [INFO]  XLSB/XLS file is Detected .
# [INFO] File loaded successfully
# [INFO] === DÉTECTION DES PRODUITS MAL CATÉGORISÉS ===
# [INFO] === Profiles Construction ===
# [INFO] Profils créés pour 596 catégories
# [INFO] Vectorisation TF-IDF en cours...
# [INFO] Analyse de 525034 produits...
# [INFO]   Progression : 0/525034
# [INFO]   Progression : 1000/525034
# [INFO]   Progression : 2000/525034
# [INFO]   Progression : 3000/525034
# [INFO]   Progression : 4000/525034
# [INFO]   Progression : 5000/525034
# [INFO]   Progression : 6000/525034
# [INFO]   Progression : 7000/525034
# [INFO]   Progression : 8000/525034
# [INFO]   Progression : 9000/525034
# [INFO]   Progression : 10000/525034
# [INFO]   Progression : 11000/525034
# [INFO]   Progression : 12000/525034
# [INFO]   Progression : 13000/525034
# [INFO]   Progression : 14000/525034
# [INFO]   Progression : 15000/525034
# [INFO]   Progression : 16000/525034
# [INFO]   Progression : 17000/525034
# [INFO]   Progression : 18000/525034
# [INFO]   Progression : 19000/525034
# [INFO]   Progression : 20000/525034
# [INFO]   Progression : 21000/525034
# [INFO]   Progression : 22000/525034
# [INFO]   Progression : 23000/525034
# [INFO]   Progression : 24000/525034
# [INFO]   Progression : 25000/525034
# [INFO]   Progression : 26000/525034
# [INFO]   Progression : 464000/525034
# [INFO]   Progression : 465000/525034
# [INFO]   Progression : 466000/525034
# [INFO]   Progression : 467000/525034
# [INFO]   Progression : 468000/525034
# [INFO]   Progression : 469000/525034
# [INFO]   Progression : 470000/525034
# [INFO]   Progression : 471000/525034
# [INFO]   Progression : 472000/525034
# [INFO]   Progression : 473000/525034
# [INFO]   Progression : 474000/525034
# [INFO]   Progression : 475000/525034
# [INFO]   Progression : 476000/525034
# [INFO]   Progression : 477000/525034
# [INFO]   Progression : 478000/525034
# [INFO]   Progression : 479000/525034
# [INFO]   Progression : 480000/525034
# [INFO]   Progression : 481000/525034
# [INFO]   Progression : 482000/525034
# [INFO]   Progression : 483000/525034
# [INFO]   Progression : 484000/525034
# [INFO]   Progression : 485000/525034
# [INFO]   Progression : 486000/525034
# [INFO]   Progression : 487000/525034
# [INFO]   Progression : 488000/525034
# [INFO]   Progression : 489000/525034
# [INFO]   Progression : 490000/525034
# [INFO]   Progression : 491000/525034
# [INFO]   Progression : 492000/525034
# [INFO]   Progression : 493000/525034
# [INFO]   Progression : 494000/525034
# [INFO]   Progression : 495000/525034
# [INFO]   Progression : 496000/525034
# [INFO]   Progression : 497000/525034
# [INFO]   Progression : 498000/525034
# [INFO]   Progression : 499000/525034
# [INFO]   Progression : 500000/525034
# [INFO]   Progression : 501000/525034
# [INFO]   Progression : 502000/525034
# [INFO]   Progression : 503000/525034
# [INFO]   Progression : 504000/525034
# [INFO]   Progression : 505000/525034
# [INFO]   Progression : 506000/525034
# [INFO]   Progression : 507000/525034
# [INFO]   Progression : 508000/525034
# [INFO]   Progression : 509000/525034
# [INFO]   Progression : 510000/525034
# [INFO]   Progression : 511000/525034
# [INFO]   Progression : 512000/525034
# [INFO]   Progression : 513000/525034
# [INFO]   Progression : 514000/525034
# [INFO]   Progression : 515000/525034
# [INFO]   Progression : 516000/525034
# [INFO]   Progression : 517000/525034
# [INFO]   Progression : 518000/525034
# [INFO]   Progression : 519000/525034
# [INFO]   Progression : 520000/525034
# [INFO]   Progression : 521000/525034
# [INFO]   Progression : 522000/525034
# [INFO]   Progression : 523000/525034
# [INFO]   Progression : 524000/525034
# [INFO]   Progression : 525000/525034
# [INFO] 135669 produits mal catégorisés détectés
# [INFO] === EXTRACTION DES DIMENSIONS ET COULEURS ===
# [INFO]  Extraction des dimensions en cours...
# [INFO] Extraction des couleurs en cours...
# [INFO] Dimensions trouvées : 226096 produits (43.1%)
# [INFO] Couleurs trouvées   : 148227 produits (28.2%)
# [INFO] Dataset saved to C:\Users\yo-un\OneDrive\Desktop\Internship_Use_Case\Ecommerce_Data\Exported_Ecommerce_sales.csv

# %% [markdown]
# Category: Data Exploration – Inspecting a DataFrame

# %%
Analyse_Categories.head(10)
# Out:
#               Category  Count  Percentage %
# 0              Matelas  35593           6.93
# 1           Lit adulte  21133           4.12
# 2  Meuble à chaussures  19105           3.72
# 3               Chaise  15591           3.04
# 4               Bureau  15409           3.00
# 5           Lave linge  14639           2.85
# 6         Bibliotheque  14129           2.75
# 7              Armoire  13316           2.59
# 8          Table basse  12530           2.44
# 9            Meuble tv  12488           2.43

# %% [markdown]
# Category: Mis-Category Correction & Verification DF

# %%
DF_with_MisCat_Verfied = Mis_Categorized_Products
DF_with_MisCat_Verfied.head(50)
# Out:
#     index                                        description  \
# 0       6  Meuble à chaussures imitation h tre 3 portes b...
# 1       7  Meuble à chaussures imitation h tre 3 portes b...
# 2       8  Meuble à chaussures gris 3 portes blanches ave...
# 3       9  Meuble à chaussures gris 3 portes blanches ave...
# 4      10  Meuble à chaussures gris 3 portes blanches ave...
# 5      11   tagère à double position tania bois imitation...
# 6      12   tagère à double position tania bois imitation...
# 7      15            Console vintage leoni motifs graphiques
# 8      26  Panneau décoratif universel 160x60 cm flower gris
# 9      37   tagère à double position tania bois blanc l 1...
# 10     38   tagère à double position tania bois blanc l 1...
# 11     41                   Lot de 3 étagères murales grises
# 12     42  Table haute detroit et 4 tabourets design indu...
# 13     43                  Commode 3 tiroirs bois blanc tomi
# 14     44  Armoire vitrine led bibliothèque 90 cm commode...
# 15     48  Canapé convertible clic clac olympia velours bleu
# 16     53  Canapé convertible clic clac scandinave slow t...
# 17     55             Fauteuil scandinave gustav tissu beige
# 18     60  Lot de 3 tables basses gigognes gigi laquées b...
# 19     61   tagère échelle scandinave klara bois blanc et...
# 20     64  Ecouteur sans fil bluetooth pour smartphone et...
# 21     68  Lot de 2 tables basses gigognes detroit 40 45 ...
# 22     69  Lot de 2 tables basses gigognes detroit 40 45 ...
# 23     76                 Meuble à chaussures 3 portes blanc
# 24     85                 Meuble à chaussures 3 portes blanc
# 25     92  Meuble à chaussures imitation h tre 3 portes b...
# 26     95  Meuble de rangement en escalier liam 4 niveaux...
# 27    101                 Meuble à chaussures 3 portes blanc
# 28    102                 Meuble à chaussures 3 portes blanc
# 29    103                 Meuble à chaussures 3 portes blanc
# 30    107    Meuble chaussures 3 portes estel en métal blanc
# 31    109  Meuble à chaussures imitation h tre 4 portes b...
# 32    112  Meuble à chaussures gris 2 portes blanches ave...
# 33    113  Couette bicolore gris foncé et gris 200x200 cm...
# 34    114  Etagère échelle 4 niveaux detroit design indus...
# 35    117  Table de bar barth 2 à 4 personnes bois blanc ...
# 36    118  Meuble à chaussures imitation h tre 2 portes b...
# 37    120  Meuble à chaussures gris 2 portes blanches ave...
# 38    128             Armoire vestiaire estel en métal noire
# 39    129                  Commode 6 tiroirs bois blanc tomi
# 40    130                  Commode 6 tiroirs bois blanc tomi
# 41    131                  Commode 6 tiroirs bois blanc tomi
# 42    132                  Commode 6 tiroirs bois blanc tomi
# 43    133                  Commode 6 tiroirs bois blanc tomi
# 44    134                  Commode 6 tiroirs bois blanc tomi
# 45    136                 Meuble à chaussures 4 portes blanc
# 46    137                 Meuble à chaussures 4 portes blanc
# 47    138                 Meuble à chaussures 4 portes blanc
# 48    139  Meuble de rangement en escalier liam 3 niveaux...
# 49    140  Etagère 5 niveaux détroit design industriel 17...
#
#        current_category  current_similarity    suggested_category  \
# 0   Meuble à chaussures               0.266      Porte chaussures
# 1   Meuble à chaussures               0.266      Porte chaussures
# 2   Meuble à chaussures               0.273      Porte chaussures
# 3   Meuble à chaussures               0.273      Porte chaussures
# 4   Meuble à chaussures               0.273      Porte chaussures
# 5          Bibliotheque               0.045          Moustiquaire
# 6          Bibliotheque               0.045          Moustiquaire
# 7                Bureau               0.026       Console de jeux
# 8               Panneau               0.506      Accessoire tapis
# 9          Bibliotheque               0.061    Motorisation volet
# 10         Bibliotheque               0.061    Motorisation volet
# 11         Bibliotheque               0.033    Accessoire biberon
# 12                Table               0.280                   Bar
# 13              Commode               0.607          Mini commode
# 14              Vitrine               0.136  Montage Bibliothèque
# 15         Canape droit               0.343      Housse clic-clac
# 16         Canape droit               0.409      Housse clic-clac
# 17             Fauteuil               0.476        Fauteuil relax
# 18          Table basse               0.072    Accessoire biberon
# 19         Bibliotheque               0.043       Chauffe biberon
# 20           Microphone               0.485    Eclairage connecté
# 21          Table basse               0.082  Recharge de poubelle
# 22          Table basse               0.082  Recharge de poubelle
# 23  Meuble à chaussures               0.314      Porte chaussures
# 24  Meuble à chaussures               0.314      Porte chaussures
# 25  Meuble à chaussures               0.279      Porte chaussures
# 26         Bibliotheque               0.252         Porte armoire
# 27  Meuble à chaussures               0.314      Porte chaussures
# 28  Meuble à chaussures               0.314      Porte chaussures
# 29  Meuble à chaussures               0.314      Porte chaussures
# 30  Meuble à chaussures               0.288      Porte chaussures
# 31  Meuble à chaussures               0.279      Porte chaussures
# 32  Meuble à chaussures               0.273      Porte chaussures
# 33    Housse de couette               0.366         Dessus de lit
# 34         Bibliotheque               0.109               Etagère
# 35                Table               0.379                   Bar
# 36  Meuble à chaussures               0.279      Porte chaussures
# 37  Meuble à chaussures               0.273      Porte chaussures
# 38    Structure armoire               0.458                 Valet
# 39         Bibliotheque               0.054          Mini commode
# 40         Bibliotheque               0.054          Mini commode
# 41         Bibliotheque               0.054          Mini commode
# 42         Bibliotheque               0.054          Mini commode
# 43         Bibliotheque               0.054          Mini commode
# 44         Bibliotheque               0.054          Mini commode
# 45  Meuble à chaussures               0.314      Porte chaussures
# 46  Meuble à chaussures               0.314      Porte chaussures
# 47  Meuble à chaussures               0.314      Porte chaussures
# 48               Buffet               0.276         Porte armoire
# 49         Bibliotheque               0.114               Etagère
#
#     suggested_similarity  confidence
# 0                  0.456       0.190
# 1                  0.456       0.190
# 2                  0.472       0.199
# 3                  0.472       0.199
# 4                  0.472       0.199
# 5                  0.488       0.443
# 6                  0.488       0.443
# 7                  0.785       0.759
# 8                  0.673       0.167
# 9                  0.494       0.433
# 10                 0.494       0.433
# 11                 0.723       0.689
# 12                 0.521       0.241
# 13                 0.903       0.297
# 14                 0.495       0.359
# 15                 0.685       0.342
# 16                 0.677       0.268
# 17                 0.611       0.134
# 18                 0.831       0.758
# 19                 0.360       0.317
# 20                 0.803       0.318
# 21                 0.591       0.509
# 22                 0.591       0.509
# 23                 0.574       0.260
# 24                 0.574       0.260
# 25                 0.487       0.208
# 26                 0.679       0.427
# 27                 0.574       0.260
# 28                 0.574       0.260
# 29                 0.574       0.260
# 30                 0.553       0.265
# 31                 0.487       0.208
# 32                 0.472       0.199
# 33                 0.534       0.169
# 34                 0.437       0.327
# 35                 0.612       0.233
# 36                 0.487       0.208
# 37                 0.472       0.199
# 38                 0.597       0.139
# 39                 0.903       0.850
# 40                 0.903       0.850
# 41                 0.903       0.850
# 42                 0.903       0.850
# 43                 0.903       0.850
# 44                 0.903       0.850
# 45                 0.574       0.260
# 46                 0.574       0.260
# 47                 0.574       0.260
# 48                 0.692       0.417
# 49                 0.465       0.351

# %% [markdown]
# DataFrame With corrected Categories

# %%
DF_With_Correct_Category= Cat_Verified_df
DF_With_Correct_Category.head(50)
# Out:
#         Cod_cmd                                    Libellé produit  \
# 0   182210782.0       Table basse carrée detroit design industriel
# 1   182082437.0                  Ours en peluche géant 150 cm brun
# 2   182095765.0                 Ours en peluche géant 100 cm blanc
# 3   182615392.0    Lot de 4 chaises mia noires pour salle à manger
# 4   184222081.0                 Meuble tv falko bois blanc et gris
# 5   182603100.0                 Meuble tv falko bois blanc et gris
# 6   182086675.0  Meuble à chaussures imitation h tre 3 portes b...
# 7   181717709.0  Meuble à chaussures imitation h tre 3 portes b...
# 8   181941387.0  Meuble à chaussures gris 3 portes blanches ave...
# 9   182374701.0  Meuble à chaussures gris 3 portes blanches ave...
# 10  182064643.0  Meuble à chaussures gris 3 portes blanches ave...
# 11  182074852.0   tagère à double position tania bois imitation...
# 12  182056932.0   tagère à double position tania bois imitation...
# 13  182113174.0  Table à manger georgia 6 personnes blanche et ...
# 14  183227003.0  Table à manger georgia 6 personnes blanche et ...
# 15  181586231.0            Console vintage leoni motifs graphiques
# 16  182077033.0  Table à manger georgia 6 personnes blanche et ...
# 17  182082962.0  Table à manger georgia 6 personnes blanche et ...
# 18  182325676.0  Table à manger georgia 6 personnes blanche et ...
# 19  182083368.0  Banc d entrée capitonné en bambou tissu gris f...
# 20  182109464.0  Banc d entrée capitonné en bambou tissu gris f...
# 21  181961372.0  Banc d entrée capitonné en bambou tissu gris f...
# 22  182111760.0      Meuble tv falko bois blanc et imitation h tre
# 23  182100280.0  Meuble tv effie scandinave 3 tiroirs bois blan...
# 24  183227003.0  Lot de 6 chaises romane noires bandeau blanc p...
# 25  184167233.0  Lot de 6 chaises romane noires bandeau blanc p...
# 26  182064835.0  Panneau décoratif universel 160x60 cm flower gris
# 27  181916701.0       Bibliothèque vintage noemi bois pied épingle
# 28  182016808.0  Lot de 6 chaises romane grises pour salle à ma...
# 29  182083354.0  Table à manger georgia 8 personnes h tre et bl...
# 30  182102565.0  Lot de 4 chaises mia noires liseré blanc pour ...
# 31  182109632.0  Lot de 4 chaises mia noires liseré blanc pour ...
# 32  182082962.0  Lot de 4 chaises mia noires liseré blanc pour ...
# 33  183173555.0  Lot de 4 chaises pia grises et blanches pour s...
# 34  182100280.0  Table basse effie plateau relevable bois blanc...
# 35  183912408.0  Lot de 6 chaises romane noires bandeau blanc p...
# 36  182102534.0  Lot de 6 chaises romane noires bandeau blanc p...
# 37  182440445.0   tagère à double position tania bois blanc l 1...
# 38  183072450.0   tagère à double position tania bois blanc l 1...
# 39  183278786.0  Meuble tv effie scandinave 2 portes bois blanc...
# 40  182212010.0  Lot de 2 tables de chevet bois olga fa on h tr...
# 41  182077852.0                   Lot de 3 étagères murales grises
# 42  182065640.0  Table haute detroit et 4 tabourets design indu...
# 43  183810947.0                  Commode 3 tiroirs bois blanc tomi
# 44  182730423.0  Armoire vitrine led bibliothèque 90 cm commode...
Autre vendeur   Canapé Salon Séjour             Meuble tv
# 48  Autre vendeur   Canapé Salon Séjour      Housse clic-clac
# 49  Autre vendeur   Canapé Salon Séjour                Chaise
#
#     Date de commande  Montant cmd  Quantité  Prix transport  \
# 0            44216.0        244.0       4.0            6.67
# 1            44213.0         28.0       1.0            9.92
# 2            44214.0         15.0       1.0            9.92
# 3            44219.0        385.0       2.0           20.75
# 4            44238.0         61.0       1.0           19.08
# 5            44219.0         31.0       1.0            1.67
# 6            44213.0         86.0       1.0           16.58
# 7            44207.0         86.0       1.0           16.58
# 8            44213.0         60.0       1.0            1.67
# 9            44217.0        206.0       2.0           18.25
# 10           44213.0         86.0       1.0           16.58
# 11           44213.0         79.0       1.0           16.58
# 12           44213.0         79.0       1.0           16.58
# 13           44214.0        134.0       1.0           27.42
# 14           44226.0        156.0       1.0           27.42
# 15           44205.0         90.0       1.0           27.42
# 16           44213.0        134.0       1.0           27.42
# 17           44213.0        134.0       1.0           27.42
# 18           44216.0        141.0       1.0           27.42
# 19           44213.0         29.0       1.0            6.66
# 20           44214.0         80.0       2.0            8.32
# 21           44214.0         29.0       1.0            6.66
# 22           44214.0         66.0       1.0           19.08
# 23           44214.0         75.0       1.0            1.67
# 24           44226.0        133.0       1.0            1.67
# 25           44237.0        156.0       1.0           19.08
# 26           44214.0        264.0       3.0           30.75
# 27           44210.0         75.0       1.0            1.67
# 28           44215.0        163.0       1.0           19.08
# 29           44213.0        192.0       1.0           27.42
# 30           44214.0        400.0       2.0           20.75
# 31           44214.0        400.0       2.0           20.75
# 32           44213.0        169.0       1.0            1.67
# 33           44227.0        229.0       1.0           19.08
# 34           44214.0        120.0       1.0           27.42
# 35           44236.0        156.0       1.0           19.08
# 36           44214.0        133.0       1.0            1.67
# 37           44219.0         79.0       1.0           16.58
# 38           44225.0         79.0       1.0           16.58
# 39           44233.0         67.0       1.0            1.67
# 40           44216.0         28.0       1.0            1.67
# 41           44213.0         26.0       1.0           18.25
# 42           44213.0        149.0       1.0           27.42
# 43           44233.0        120.0       1.0           27.42
# 44           44220.0        435.0       1.0           49.99
# 45           44213.0        274.0       1.0           24.99
# 46           44217.0        260.0       1.0           33.33
# 47           44221.0        231.0       1.0           24.99
# 48           44218.0        333.0       1.0           41.67
# 49           44225.0        209.0       1.0           15.83
#
#     Délai transport annoncé
# 0                      10.0
# 1                      10.0
# 2                      10.0
# 3                      10.0
# 4                      10.0
# 5                      10.0
# 6                      10.0
# 7                      10.0
# 8                      10.0
# 9                      10.0
# 10                     10.0
# 11                     10.0
# 12                     10.0
# 13                     10.0
# 14                     10.0
# 15                     10.0
# 16                     10.0
# 17                     10.0
# 18                     10.0
# 19                     10.0
# 20                     10.0
# 21                     10.0
# 22                     10.0
# 23                     10.0
# 24                     10.0
# 25                     10.0
# 26                     10.0
# 27                     10.0
# 28                     10.0
# 29                     10.0
# 30                     10.0
# 31                     10.0
# 32                     10.0
# 33                     10.0
# 34                     10.0
# 35                     10.0
# 36                     10.0
# 37                     10.0
# 38                     10.0
# 39                     10.0
# 40                     10.0
# 41                     10.0
# 42                     10.0
# 43                     10.0
# 44                     15.0
# 45                     10.0
# 46                     15.0
# 47                     10.0
# 48                     11.0
# 49                     11.0

# %% [markdown]
# Clean & Final Dataset

# %%
Final_Dataset.head(50)
# Out:
#         Cod_cmd                                    Libellé produit  \
# 0   182210782.0       Table basse carrée detroit design industriel
# 1   182082437.0                  Ours en peluche géant 150 cm brun
# 2   182095765.0                 Ours en peluche géant 100 cm blanc
# 3   182615392.0    Lot de 4 chaises mia noires pour salle à manger
# 4   184222081.0                 Meuble tv falko bois blanc et gris
# 5   182603100.0                 Meuble tv falko bois blanc et gris
# 6   182086675.0  Meuble à chaussures imitation h tre 3 portes b...
# 7   181717709.0  Meuble à chaussures imitation h tre 3 portes b...
# 8   181941387.0  Meuble à chaussures gris 3 portes blanches ave...
# 9   182374701.0  Meuble à chaussures gris 3 portes blanches ave...
# 10  182064643.0  Meuble à chaussures gris 3 portes blanches ave...
# 11  182074852.0   tagère à double position tania bois imitation...
# 12  182056932.0   tagère à double position tania bois imitation...
# 13  182113174.0  Table à manger georgia 6 personnes blanche et ...
# 14  183227003.0  Table à manger georgia 6 personnes blanche et ...
# 15  181586231.0            Console vintage leoni motifs graphiques
# 16  182077033.0  Table à manger georgia 6 personnes blanche et ...
# 17  182082962.0  Table à manger georgia 6 personnes blanche et ...
# 18  182325676.0  Table à manger georgia 6 personnes blanche et ...
# 19  182083368.0  Banc d entrée capitonné en bambou tissu gris f...
# 20  182109464.0  Banc d entrée capitonné en bambou tissu gris f...
# 21  181961372.0  Banc d entrée capitonné en bambou tissu gris f...
# 22  182111760.0      Meuble tv falko bois blanc et imitation h tre
# 23  182100280.0  Meuble tv effie scandinave 3 tiroirs bois blan...
# 24  183227003.0  Lot de 6 chaises romane noires bandeau blanc p...
# 25  184167233.0  Lot de 6 chaises romane noires bandeau blanc p...
# 26  182064835.0  Panneau décoratif universel 160x60 cm flower gris
# 27  181916701.0       Bibliothèque vintage noemi bois pied épingle
# 28  182016808.0  Lot de 6 chaises romane grises pour salle à ma...
# 29  182083354.0  Table à manger georgia 8 personnes h tre et bl...
# 30  182102565.0  Lot de 4 chaises mia noires liseré blanc pour ...
# 31  182109632.0  Lot de 4 chaises mia noires liseré blanc pour ...
# 32  182082962.0  Lot de 4 chaises mia noires liseré blanc pour ...
# 33  183173555.0  Lot de 4 chaises pia grises et blanches pour s...
# 34  182100280.0  Table basse effie plateau relevable bois blanc...
# 35  183912408.0  Lot de 6 chaises romane noires bandeau blanc p...
# 36  182102534.0  Lot de 6 chaises romane noires bandeau blanc p...
# 37  182440445.0   tagère à double position tania bois blanc l 1...
# 38  183072450.0   tagère à double position tania bois blanc l 1...
# 39  183278786.0  Meuble tv effie scandinave 2 portes bois blanc...
# 40  182212010.0  Lot de 2 tables de chevet bois olga fa on h tr...
# 41  182077852.0                   Lot de 3 étagères murales grises
# 42  182065640.0  Table haute detroit et 4 tabourets design indu...
# 43  183810947.0                  Commode 3 tiroirs bois blanc tomi
# 44  182730423.0  Armoire vitrine led bibliothèque 90 cm commode...
# 45  182061409.0  Meuble tv pablo 230 cm avec led noir mat et no...
# 46  182377592.0  Meuble tv spider big à led en blanc mat avec p...
# 47  182696018.0  Meuble tv savelli led blanc mat et portes noir...
# 48  182447837.0  Canapé convertible clic clac olympia velours bleu
# 49  183127166.0       Lot de 4 chaises scandinaves gao tissu beige
#
#           Vendeur               Univers                Nature  \
# 0   Autre vendeur   Canapé Salon Séjour           Table basse
# 1   Autre vendeur           Enfant Bébé               Peluche
# 2   Autre vendeur           Enfant Bébé               Peluche
# 3   Autre vendeur   Canapé Salon Séjour                Chaise
# 4   Autre vendeur   Canapé Salon Séjour             Meuble tv
# 5   Autre vendeur   Canapé Salon Séjour             Meuble tv
# 6   Autre vendeur      Bureau Rangement      Porte chaussures
# 7   Autre vendeur      Bureau Rangement      Porte chaussures
# 8   Autre vendeur      Bureau Rangement      Porte chaussures
# 9   Autre vendeur      Bureau Rangement      Porte chaussures
# 10  Autre vendeur      Bureau Rangement      Porte chaussures
# 11  Autre vendeur      Bureau Rangement          Moustiquaire
# 12  Autre vendeur      Bureau Rangement          Moustiquaire
# 13  Autre vendeur   Canapé Salon Séjour                 Table
# 14  Autre vendeur   Canapé Salon Séjour                 Table
# 15  Autre vendeur      Bureau Rangement       Console de jeux
# 16  Autre vendeur   Canapé Salon Séjour                 Table
# 17  Autre vendeur   Canapé Salon Séjour                 Table
# 18  Autre vendeur   Canapé Salon Séjour                 Table
# 19  Autre vendeur       Chambre Literie           Banc de lit
# 20  Autre vendeur       Chambre Literie           Banc de lit
# 21  Autre vendeur       Chambre Literie           Banc de lit
# 22  Autre vendeur   Canapé Salon Séjour             Meuble tv
# 23  Autre vendeur   Canapé Salon Séjour             Meuble tv
# 24  Autre vendeur   Canapé Salon Séjour                Chaise
# 25  Autre vendeur   Canapé Salon Séjour                Chaise
# 26  Autre vendeur  Jardin Loisirs Sport      Accessoire tapis
# 27  Autre vendeur      Bureau Rangement          Bibliotheque
# 28  Autre vendeur   Canapé Salon Séjour                Chaise
# 29  Autre vendeur   Canapé Salon Séjour                 Table
# 30  Autre vendeur   Canapé Salon Séjour                Chaise
# 31  Autre vendeur   Canapé Salon Séjour                Chaise
# 32  Autre vendeur   Canapé Salon Séjour                Chaise
# 33  Autre vendeur   Canapé Salon Séjour                Chaise
# 34  Autre vendeur   Canapé Salon Séjour           Table basse
# 35  Autre vendeur   Canapé Salon Séjour                Chaise
# 36  Autre vendeur   Canapé Salon Séjour                Chaise
# 37  Autre vendeur      Bureau Rangement    Motorisation volet
# 38  Autre vendeur      Bureau Rangement    Motorisation volet
# 39  Autre vendeur   Canapé Salon Séjour             Meuble tv
# 40  Autre vendeur       Chambre Literie                Chevet
# 41  Autre vendeur      Bureau Rangement    Accessoire biberon
# 42  Autre vendeur   Canapé Salon Séjour                   Bar
# 43  Autre vendeur       Chambre Literie          Mini commode
# 44  Autre vendeur   Canapé Salon Séjour  Montage Bibliothèque
# 45  Autre vendeur   Canapé Salon Séjour             Meuble tv
# 46  Autre vendeur   Canapé Salon Séjour             Meuble tv
# 47  Autre vendeur   Canapé Salon Séjour             Meuble tv
# 48  Autre vendeur   Canapé Salon Séjour      Housse clic-clac
# 49  Autre vendeur   Canapé Salon Séjour                Chaise
#
#     Date de commande  Montant cmd  Quantité  Prix transport  \
# 0            44216.0        244.0       4.0            6.67
# 1            44213.0         28.0       1.0            9.92
# 2            44214.0         15.0       1.0            9.92
# 3            44219.0        385.0       2.0           20.75
# 4            44238.0         61.0       1.0           19.08
# 5            44219.0         31.0       1.0            1.67
# 6            44213.0         86.0       1.0           16.58
# 7            44207.0         86.0       1.0           16.58
# 8            44213.0         60.0       1.0            1.67
# 9            44217.0        206.0       2.0           18.25
# 10           44213.0         86.0       1.0           16.58
# 11           44213.0         79.0       1.0           16.58
# 12           44213.0         79.0       1.0           16.58
# 13           44214.0        134.0       1.0           27.42
# 14           44226.0        156.0       1.0           27.42
# 15           44205.0         90.0       1.0           27.42
# 16           44213.0        134.0       1.0           27.42
# 17           44213.0        134.0       1.0           27.42
# 18           44216.0        141.0       1.0           27.42
# 19           44213.0         29.0       1.0            6.66
# 20           44214.0         80.0       2.0            8.32
# 21           44214.0         29.0       1.0            6.66
# 22           44214.0         66.0       1.0           19.08
# 23           44214.0         75.0       1.0            1.67
# 24           44226.0        133.0       1.0            1.67
# 25           44237.0        156.0       1.0           19.08
# 26           44214.0        264.0       3.0           30.75
# 27           44210.0         75.0       1.0            1.67
# 28           44215.0        163.0       1.0           19.08
# 29           44213.0        192.0       1.0           27.42
# 30           44214.0        400.0       2.0           20.75
# 31           44214.0        400.0       2.0           20.75
# 32           44213.0        169.0       1.0            1.67
# 33           44227.0        229.0       1.0           19.08
# 34           44214.0        120.0       1.0           27.42
# 35           44236.0        156.0       1.0           19.08
# 36           44214.0        133.0       1.0            1.67
# 37           44219.0         79.0       1.0           16.58
# 38           44225.0         79.0       1.0           16.58
# 39           44233.0         67.0       1.0            1.67
# 40           44216.0         28.0       1.0            1.67
# 41           44213.0         26.0       1.0           18.25
# 42           44213.0        149.0       1.0           27.42
# 43           44233.0        120.0       1.0           27.42
# 44           44220.0        435.0       1.0           49.99
# 45           44213.0        274.0       1.0           24.99
# 46           44217.0        260.0       1.0           33.33
# 47           44221.0        231.0       1.0           24.99
# 48           44218.0        333.0       1.0           41.67
# 49           44225.0        209.0       1.0           15.83
#
#     Délai transport annoncé Product_Dimensions   Product_Couleurs
# 0                      10.0
# 1                      10.0                150             marron
# 2                      10.0                100              blanc
# 3                      10.0                                  noir
# 4                      10.0                     bois, gris, blanc
# 5                      10.0                     bois, gris, blanc
# 6                      10.0                                 blanc
# 7                      10.0                                 blanc
# 8                      10.0                           gris, blanc
# 9                      10.0                           gris, blanc
# 10                     10.0                           gris, blanc
# 11                     10.0                161               bois
# 12                     10.0                161               bois
# 13                     10.0                140        noir, blanc
# 14                     10.0                140        noir, blanc
# 15                     10.0                           multicolore
# 16                     10.0                140        noir, blanc
# 17                     10.0                140        noir, blanc
# 18                     10.0                140        noir, blanc
# 19                     10.0                            bois, gris
# 20                     10.0                            bois, gris
# 21                     10.0                            bois, gris
# 22                     10.0                           bois, blanc
# 23                     10.0                     bois, gris, blanc
# 24                     10.0                           noir, blanc
# 25                     10.0                           noir, blanc
# 26                     10.0             160x60               gris
# 27                     10.0                                  bois
# 28                     10.0                                  gris
# 29                     10.0                160              blanc
# 30                     10.0                           noir, blanc
# 31                     10.0                           noir, blanc
# 32                     10.0                           noir, blanc
# 33                     10.0                           gris, blanc
# 34                     10.0                     bois, gris, blanc
# 35                     10.0                           noir, blanc
# 36                     10.0                           noir, blanc
# 37                     10.0                161        bois, blanc
# 38                     10.0                161        bois, blanc
# 39                     10.0                     bois, gris, blanc
# 40                     10.0                           bois, blanc
# 41                     10.0                                  gris
# 42                     10.0
# 43                     10.0                           bois, blanc
# 44                     15.0                 90
# 45                     10.0                230               noir
# 46                     15.0                200              blanc
# 47                     10.0                157        noir, blanc
# 48                     11.0                                  bleu
# 49                     11.0                                 beige
